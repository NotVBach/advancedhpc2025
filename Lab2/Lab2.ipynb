# %% [markdown]
# Device name

# %%
from numba import cuda
cuda.get_current_device().name
# Out:
# b'NVIDIA GeForce RTX 2050'

# %% [markdown]
# Number of processor

# %%
cuda.get_current_device().MULTIPROCESSOR_COUNT
# Out:
# 16

# %% [markdown]
# Core count

# %%
cuda.get_current_device().compute_capability
# Out:
# (8, 6)

# %% [markdown]
# Memory size (include free and total memory)

# %%
free_b, total_b = cuda.current_context().get_memory_info()
print("Free memory: ", free_b/(1024**3), " Gb")
print('Total memory: ', total_b/(1024**3), " Gb")
# Out:
# Free memory:  3.5948486328125  Gb
# Total memory:  3.68023681640625  Gb

# %%
# !nvidia-smi
# Out:
# Sun Sep 28 08:33:39 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 575.64.03              Driver Version: 575.64.03      CUDA Version: 12.9     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 2050        Off |   00000000:01:00.0 Off |                  N/A |
# | N/A   41C    P8              3W /   45W |      88MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...
